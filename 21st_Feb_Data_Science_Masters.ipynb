# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
prod = input("Enter the product name to search")
# Out:
# Enter the product name to searchmobiles

# %%
flipkart_url_prod = "https://www.flipkart.com/search?q=" + prod

# %%
flipkart_url_prod
# Out:
# 'https://www.flipkart.com/search?q=mobiles'

# %%
url_client = urlopen(flipkart_url_prod)

# %%
flipkart_page = url_client.read()

# %%
flipkart_beauty = bs(flipkart_page, 'html.parser')

# %%
flipkart_beauty
# Out:
# <!DOCTYPE html>
# ...

# %%
list_of_prod = flipkart_beauty.find_all("div", {'class':'_1AtVbE col-12-12'})

# %%
len(list_of_prod)
# Out:
# 30

# %%
del list_of_prod[0:2]

# %%
list_of_prod[0].div.div.div.a['href']
# Out:
# '/apple-iphone-14-blue-128-gb/p/itmdb77f40da6b6d?pid=MOBGHWFHSV7GUFWA&lid=LSTMOBGHWFHSV7GUFWAFEQJQ4&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=89e17c64-3939-4f3c-ba87-91fccbd0470f.MOBGHWFHSV7GUFWA.SEARCH&ppt=None&ppn=None&ssid=osixrquuao0000001704107756583&qH=eb4af0bf07c16429'

# %%
prod_link = "https://www.flipkart.com" + list_of_prod[1].div.div.div.a['href']

# %%
prod_link
# Out:
# 'https://www.flipkart.com/apple-iphone-14-starlight-128-gb/p/itm3485a56f6e676?pid=MOBGHWFHABH3G73H&lid=LSTMOBGHWFHABH3G73HCNASCL&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=89e17c64-3939-4f3c-ba87-91fccbd0470f.MOBGHWFHABH3G73H.SEARCH&ppt=None&ppn=None&ssid=osixrquuao0000001704107756583&qH=eb4af0bf07c16429'

# %%
for i in list_of_prod:
    "https://www.flipkart.com" + i.div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10544\1460695901.py in <module>
#       1 for i in list_of_prod:
# ----> 2     "https://www.flipkart.com" + i.div.div.div.a['href']
#
# AttributeError: 'NoneType' object has no attribute 'a'

# %%
prod_req = requests.get(prod_link).text

# %%
prod_beauty = bs(prod_req, "html.parser")

# %%
reviews = prod_beauty.find_all('div', {'class':'_16PBlm'}, 'html.parser')

# %%
len(reviews)
# Out:
# 11

# %%
reviews[0].div.div.find('p', {'class':'_2sc7ZR _2V5EHH'}).text
# Out:
# 'Rahul Prasad '

# %%
for i in reviews:
    print(i.div.div.find('p', {'class':'_2sc7ZR _2V5EHH'}).text)
# Out:
# Rahul Prasad
# Narendar Redyy
# Tara singh mehra
# Flipkart Customer
# Avi Nash
# Ajay Kumar
# Waqar ahmed
# Ashwini  biswal
# Sanket  Hange
# Vipul Rai
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10544\3544632240.py in <module>
#       1 for i in reviews:
# ----> 2     print(i.div.div.find('p', {'class':'_2sc7ZR _2V5EHH'}).text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
reviews[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in reviews:
    print(i.div.div.div.div.text)
# Out:
# 5
# 4
# 5
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10544\1137619687.py in <module>
#       1 for i in reviews:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
reviews[0].div.div.div.p.text
# Out:
# 'Fabulous!'

# %%
for i in reviews:
    print(i.div.div.div.p.text)
# Out:
# Fabulous!
# Very Good
# Great product
# Great product
# Just wow!
# Excellent
# Best in the market!
# Good quality product
# Must buy!
# Awesome
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10544\2236249432.py in <module>
#       1 for i in reviews:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
reviews[0].div.div.find('div',{'class':''}).text
# Out:
# 'Best smart phone under this price range compare to other phones in 2023 if you see overall build quality, performance and Camera with autofocus and video action mode are awesome50% extra RAM compared to iPhone 13 and other more features. Best time to upgrade to iPhone 14 . I am so happy See Low light photos are amazing..READ MORE'

# %%
for i in reviews:
    print(i.div.div.find('div',{'class':''}).text)
# Out:
# Best smart phone under this price range compare to other phones in 2023 if you see overall build quality, performance and Camera with autofocus and video action mode are awesome50% extra RAM compared to iPhone 13 and other more features. Best time to upgrade to iPhone 14 . I am so happy See Low light photos are amazing..READ MORE
# Nice UI and FastREAD MORE
# Nice camera but battery drain fast specially on video recordingREAD MORE
# Damn such a great phone. Camera is really good, battery lasts long enough, super smooth even though its just 60 hz XDR display. Videos with action mode on are insanely stable and crisp.The night mode can take some really good shots jn low light conditions .The whole apple environment itself is so seamless. I shifted from android to iPhone and it barely took any time since I had iPad and a mac already. With a just a few clicks the phone was ready to go.READ MORE
# GoodREAD MORE
# Just amazing!READ MORE
# ...
