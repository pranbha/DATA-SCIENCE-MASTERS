# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df['Name'][2:11]
# Out:
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df.loc[2:10, ["Name"]]
# Out:
#                                                  Name
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# 6                             McCarthy, Mr. Timothy J
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                 Nasser, Mrs. Nicholas (Adele Achem)
# 10                    Sandstrom, Miss. Marguerite Rut

# %%
s = pd.Series(list(df['Name'][2:7]), index=['A','B','C',"D",'E'])

# %%
s
# Out:
# A                          Heikkinen, Miss. Laina
# B    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# C                        Allen, Mr. William Henry
# D                                Moran, Mr. James
# E                         McCarthy, Mr. Timothy J
# dtype: object

# %%
s1=df['Name'][5:10]

# %%
s+s1
# Out:
# A    NaN
# B    NaN
# C    NaN
# D    NaN
# E    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# dtype: object

# %%
s.append(s1)
# Out:
# C:\Users\pranj\AppData\Local\Temp\ipykernel_15196\137217768.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s1)
# A                               Heikkinen, Miss. Laina
# B         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# C                             Allen, Mr. William Henry
# D                                     Moran, Mr. James
# E                              McCarthy, Mr. Timothy J
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId', axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Survived')
# Out:
#           Pclass                                               Name     Sex  \
# Survived
# 0              3                            Braund, Mr. Owen Harris    male
# 1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1              3                             Heikkinen, Miss. Laina  female
# 0              3                           Allen, Mr. William Henry    male
# 0              3                                   Moran, Mr. James    male
# ...          ...                                                ...     ...
# 0              2                              Montvila, Rev. Juozas    male
# 1              1                       Graham, Miss. Margaret Edith  female
# 0              3           Johnston, Miss. Catherine Helen "Carrie"  female
# 1              1                              Behr, Mr. Karl Howell    male
# 0              3                                Dooley, Mr. Patrick    male
#
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Survived', inplace=True)

# %%
df
# Out:
#           Pclass                                               Name     Sex  \
# Survived
# 0              3                            Braund, Mr. Owen Harris    male
# 1              1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1              3                             Heikkinen, Miss. Laina  female
# 0              3                           Allen, Mr. William Henry    male
# 0              3                                   Moran, Mr. James    male
# ...          ...                                                ...     ...
# 0              2                              Montvila, Rev. Juozas    male
# 1              1                       Graham, Miss. Margaret Edith  female
# 0              3           Johnston, Miss. Catherine Helen "Carrie"  female
# 1              1                              Behr, Mr. Karl Howell    male
# 0              3                                Dooley, Mr. Patrick    male
#
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Allen, Mr. William Henry                                 3    male  35.0
# Moran, Mr. James                                         3    male   NaN
# ...                                                    ...     ...   ...
# Montvila, Rev. Juozas                                    2    male  27.0
# Graham, Miss. Margaret Edith                             1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"                 3  female   NaN
# Behr, Mr. Karl Howell                                    1    male  26.0
# Dooley, Mr. Patrick                                      3    male  32.0
#
#                                                     SibSp  Parch  \
# Name
# ...

# %%
df.loc["Braund, Mr. Owen Harris"]
# Out:
# Pclass              3
# Sex              male
# Age              22.0
# SibSp               1
# Parch               0
# Ticket      A/5 21171
# Fare             7.25
# Cabin             NaN
# Embarked            S
# Name: Braund, Mr. Owen Harris, dtype: object

# %%
df.iloc[3]
# Out:
# Pclass           3
# Sex           male
# Age           35.0
# SibSp            0
# Parch            0
# Ticket      373450
# Fare          8.05
# Cabin          NaN
# Embarked         S
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Pclass     Sex   Age  \
# 0                              Braund, Mr. Owen Harris       3    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                               Heikkinen, Miss. Laina       3  female  26.0
# 3                             Allen, Mr. William Henry       3    male  35.0
# 4                                     Moran, Mr. James       3    male   NaN
# ..                                                 ...     ...     ...   ...
# 885                              Montvila, Rev. Juozas       2    male  27.0
# 886                       Graham, Miss. Margaret Edith       1  female  19.0
# 887           Johnston, Miss. Catherine Helen "Carrie"       3  female   NaN
# 888                              Behr, Mr. Karl Howell       1    male  26.0
# 889                                Dooley, Mr. Patrick       3    male  32.0
#
# ...

# %%
dict={'key1':[1,2,3,4],
      'key2':[3,4,5,6],
      'key3':[5,6,7,8]}

# %%
pd.DataFrame(dict)
# Out:
#    key1  key2  key3
# 0     1     3     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
df1=pd.read_csv("taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1.fillna('pran', inplace = True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency      pran                  pran
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df.groupby('Pclass').mean()
# Out:
#               Age     SibSp     Parch       Fare
# Pclass
# 1       38.250919  0.413953  0.358140  84.299128
# 2       29.877630  0.402174  0.380435  20.662183
# 3       25.140620  0.615071  0.393075  13.675550

# %%
df.groupby('Pclass').sum()
# Out:
#             Age  SibSp  Parch        Fare
# Pclass
# 1       7076.42     89     77  18124.3125
# 2       5168.83     74     70   3801.8417
# 3       8924.92    302    193   6714.6951

# %%
df.groupby('Sex').sum()
# Out:
#         Pclass       Age  SibSp  Parch        Fare
# Sex
# female     677   7251.00    217    204  13913.5628
# male      1379  13919.17    248    136  14727.2865

# %%
df.groupby('Sex').sum()['Fare']
# Out:
# Sex
# female    13913.5628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
df.groupby('Sex').mean()['Age']
# Out:
# Sex
# female    27.888462
# male      30.726645
# Name: Age, dtype: float64

# %%
df3 = df.groupby('Pclass').sum()

# %%
df3.T                # df3.transpose
# Out:
# Pclass           1          2          3
# Age      7076.4200  5168.8300  8924.9200
# SibSp      89.0000    74.0000   302.0000
# Parch      77.0000    70.0000   193.0000
# Fare    18124.3125  3801.8417  6714.6951

# %%
df
# Out:
#                                                   Name  Pclass     Sex   Age  \
# 0                              Braund, Mr. Owen Harris       3    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                               Heikkinen, Miss. Laina       3  female  26.0
# 3                             Allen, Mr. William Henry       3    male  35.0
# 4                                     Moran, Mr. James       3    male   NaN
# ..                                                 ...     ...     ...   ...
# 885                              Montvila, Rev. Juozas       2    male  27.0
# 886                       Graham, Miss. Margaret Edith       1  female  19.0
# 887           Johnston, Miss. Catherine Helen "Carrie"       3  female   NaN
# 888                              Behr, Mr. Karl Howell       1    male  26.0
# 889                                Dooley, Mr. Patrick       3    male  32.0
#
# ...

# %%
df11 = df[['Name', 'Pclass', 'Sex']][0:5]

# %%
df11
# Out:
#                                                 Name  Pclass     Sex
# 0                            Braund, Mr. Owen Harris       3    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female
# 2                             Heikkinen, Miss. Laina       3  female
# 3                           Allen, Mr. William Henry       3    male
# 4                                   Moran, Mr. James       3    male

# %%
df12 = df[['Name', 'Pclass', 'Sex']][5:10]

# %%
df12
# Out:
#                                                 Name  Pclass     Sex
# 5                            McCarthy, Mr. Timothy J       1    male
# 6                     Palsson, Master. Gosta Leonard       3    male
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female
# 8                Nasser, Mrs. Nicholas (Adele Achem)       2  female
# 9                    Sandstrom, Miss. Marguerite Rut       3  female

# %%
pd.concat([df11,df12])
# Out:
#                                                 Name  Pclass     Sex
# 0                            Braund, Mr. Owen Harris       3    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female
# 2                             Heikkinen, Miss. Laina       3  female
# 3                           Allen, Mr. William Henry       3    male
# 4                                   Moran, Mr. James       3    male
# 5                            McCarthy, Mr. Timothy J       1    male
# 6                     Palsson, Master. Gosta Leonard       3    male
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       3  female
# 8                Nasser, Mrs. Nicholas (Adele Achem)       2  female
# 9                    Sandstrom, Miss. Marguerite Rut       3  female

# %%
df5 = pd.concat([df11,df12], axis=1)

# %%
df5.fillna("pran", inplace=True)

# %%
df5
# Out:
#                                                 Name Pclass     Sex  \
# 0                            Braund, Mr. Owen Harris    3.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1.0  female
# 2                             Heikkinen, Miss. Laina    3.0  female
# 3                           Allen, Mr. William Henry    3.0    male
# 4                                   Moran, Mr. James    3.0    male
# 5                                               pran   pran    pran
# 6                                               pran   pran    pran
# 7                                               pran   pran    pran
# 8                                               pran   pran    pran
# 9                                               pran   pran    pran
#
#                                                 Name Pclass     Sex
# 0                                               pran   pran    pran
# 1                                               pran   pran    pran
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,3,4], 'key2':[3,4,5,6], 'key3':[5,6,7,8]})

# %%
data2 = pd.DataFrame({'key1':[1,6,3,8], 'key4':[12,34,45,67], 'key5':[12,23,34,45]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     3     5
# 1     2     4     6
# 2     3     5     7
# 3     4     6     8

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    12    12
# 1     6    34    23
# 2     3    45    34
# 3     8    67    45

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     3     5    12    12
# 1     3     5     7    45    34

# %%
pd.merge(data1,data2, how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     3     5  12.0  12.0
# 1     2     4     6   NaN   NaN
# 2     3     5     7  45.0  34.0
# 3     4     6     8   NaN   NaN

# %%
pd.merge(data1,data2, how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   3.0   5.0    12    12
# 1     6   NaN   NaN    34    23
# 2     3   5.0   7.0    45    34
# 3     8   NaN   NaN    67    45

# %%
pd.merge(data1,data2, how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   3.0   5.0  12.0  12.0
# 1     2   4.0   6.0   NaN   NaN
# 2     3   5.0   7.0  45.0  34.0
# 3     4   6.0   8.0   NaN   NaN
# 4     6   NaN   NaN  34.0  23.0
# 5     8   NaN   NaN  67.0  45.0

# %%
pd.merge(data1,data2, how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     3     5       1    12    12
# 1        1     3     5       6    34    23
# 2        1     3     5       3    45    34
# 3        1     3     5       8    67    45
# 4        2     4     6       1    12    12
# 5        2     4     6       6    34    23
# 6        2     4     6       3    45    34
# 7        2     4     6       8    67    45
# 8        3     5     7       1    12    12
# 9        3     5     7       6    34    23
# 10       3     5     7       3    45    34
# 11       3     5     7       8    67    45
# 12       4     6     8       1    12    12
# 13       4     6     8       6    34    23
# 14       4     6     8       3    45    34
# 15       4     6     8       8    67    45

# %%
pd.merge(data1,data2, how='left', on='key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     3     5  12.0  12.0
# 1     2     4     6   NaN   NaN
# 2     3     5     7  45.0  34.0
# 3     4     6     8   NaN   NaN

# %%
pd.merge(data1,data2, how='left', left_on='key2', right_on='key4')
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     3     5     NaN   NaN   NaN
# 1       2     4     6     NaN   NaN   NaN
# 2       3     5     7     NaN   NaN   NaN
# 3       4     6     8     NaN   NaN   NaN

# %%
dat1=pd.DataFrame({'key1':[1,2,3,4],'key2':[3,4,5,6],'key3':[5,6,7,8]},index=['a','b','c','d'])

# %%
dat1
# Out:
#    key1  key2  key3
# a     1     3     5
# b     2     4     6
# c     3     5     7
# d     4     6     8

# %%
dat2=pd.DataFrame({'key11':[5,6,7,8],'key22':[12,23,3,5],'key33':[8,7,5,2]},index=['a','b','e','f'])

# %%
dat2
# Out:
#    key11  key22  key33
# a      5     12      8
# b      6     23      7
# e      7      3      5
# f      8      5      2

# %%
dat1.join(dat2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     3     5    5.0   12.0    8.0
# b     2     4     6    6.0   23.0    7.0
# c     3     5     7    NaN    NaN    NaN
# d     4     6     8    NaN    NaN    NaN

# %%
dat1.join(dat2, how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     3     5      5     12      8
# b     2     4     6      6     23      7

# %%
dat1.join(dat2, how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   3.0   5.0    5.0   12.0    8.0
# b   2.0   4.0   6.0    6.0   23.0    7.0
# c   3.0   5.0   7.0    NaN    NaN    NaN
# d   4.0   6.0   8.0    NaN    NaN    NaN
# e   NaN   NaN   NaN    7.0    3.0    5.0
# f   NaN   NaN   NaN    8.0    5.0    2.0

# %%
def into_inr(fare):
    return fare*80

# %%
df['Fare-INR'] = df['Fare'].apply(into_inr) # apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                 Name  Pclass     Sex   Age  \
# 0                            Braund, Mr. Owen Harris       3    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                             Heikkinen, Miss. Laina       3  female  26.0
# 3                           Allen, Mr. William Henry       3    male  35.0
# 4                                   Moran, Mr. James       3    male   NaN
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  Fare-INR
# 0      1      0         A/5 21171   7.2500   NaN        S   580.000
# 1      1      0          PC 17599  71.2833   C85        C  5702.664
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S   634.000
# 3      0      0            373450   8.0500   NaN        S   644.000
# 4      0      0            330877   8.4583   NaN        Q   676.664

# %%
df['name-len'] = df['Name'].apply(len)

# %%
df
# Out:
#                                                   Name  Pclass     Sex   Age  \
# 0                              Braund, Mr. Owen Harris       3    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                               Heikkinen, Miss. Laina       3  female  26.0
# 3                             Allen, Mr. William Henry       3    male  35.0
# 4                                     Moran, Mr. James       3    male   NaN
# ..                                                 ...     ...     ...   ...
# 885                              Montvila, Rev. Juozas       2    male  27.0
# 886                       Graham, Miss. Margaret Edith       1  female  19.0
# 887           Johnston, Miss. Catherine Helen "Carrie"       3  female   NaN
# 888                              Behr, Mr. Karl Howell       1    male  26.0
# 889                                Dooley, Mr. Patrick       3    male  32.0
#
# ...

# %%
max(df['Fare-INR'])
# Out:
# 40986.336

# %%
def segregating(fare):
    if fare<10:
        return 'Cheap'
    elif fare>=10 and fare<20:
        return 'Mid'
    else:
        return 'High'

# %%
df['Fare_category']=df['Fare'].apply(segregating)

# %%
df.head()
# Out:
#                                                 Name  Pclass     Sex   Age  \
# 0                            Braund, Mr. Owen Harris       3    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female  38.0
# 2                             Heikkinen, Miss. Laina       3  female  26.0
# 3                           Allen, Mr. William Henry       3    male  35.0
# 4                                   Moran, Mr. James       3    male   NaN
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  Fare-INR  name-len  \
# 0      1      0         A/5 21171   7.2500   NaN        S   580.000        23
# 1      1      0          PC 17599  71.2833   C85        C  5702.664        51
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S   634.000        22
# 3      0      0            373450   8.0500   NaN        S   644.000        24
# 4      0      0            330877   8.4583   NaN        Q   676.664        16
#
#   Fare_category
# 0         Cheap
# ...
